# %% [markdown]
# # 1.2 Scale Dataset from ClimateWins
#
# Objective: Data cleaning and scale dataset as preparation for further analysis.
#
# ### This script contains the following:
#
# ### 1. [Importing Libraries](#import_libraries)
#
# ### 2. [Import Data](#import_data)
#
# ### 3. [Missing Values](#clean)
#
# ### 4. [Scaling Data](#scaling)

# %% [markdown]
# ## 1. Importing Libraries <a id='import_libraries'></a>

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 2. Import Data <a id='import_data'></a>

# %%
#create a path to the folder
path = r'/content/drive/MyDrive/Careerfoundary/Machine_learning'

# %%
#import the dataset
df = pd.read_csv(os.path.join(path, '02 Data', 'Original_Data', 'weather_dataset.csv'), index_col = False)

# %%
df.head(5)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
df.shape
# Out:
# (22950, 170)

# %%
#reset the index
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %% [markdown]
# # 3. Missing Values <a id='clean'></a>

# %%
df.shape
# Out:
# (22950, 171)

# %%
# Check for missing values

# %%
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
#Discard Rows with Missing Data
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22950, 171)

# %%
# There are no missing values

# %% [markdown]
# # 4. Scaling Data<a id='scaling'></a>

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
#create new df with scaled data

df_scaled.head()
# Out:
#          id      DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# 0 -1.731975  19600101 -1.599964           0.660514          -0.02793
# 1 -1.731824  19600102 -1.599964           0.244897          -0.02793
# 2 -1.731673  19600103 -1.599964           1.076130          -0.02793
# 3 -1.731523  19600104 -1.599964          -1.001953          -0.02793
# 4 -1.731372  19600105 -1.599964           0.244897          -0.02793
#
#    BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# 0        0.826097       -0.001949               -1.101066
# 1        0.735760       -0.001949               -1.058108
# 2        1.277781       -0.001949               -1.251420
# 3        1.458455       -0.001949               -0.821838
# 4        1.729466       -0.001949               -0.746661
#
#    BASEL_precipitation  BASEL_snow_depth  ...  VALENTIA_cloud_cover  \
# 0            -0.265148         -0.179228  ...             -0.443701
# ...

# %%
# Compare the original vs. scaled data

df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
# Export dataframe as .pkl
df_scaled.to_csv(os.path.join(path, '02 Data', 'Prepared_Data', 'DataSet_scaled.csv'), index=False)
